# %% [markdown]
# ##01. Python 변수
# * 변수란? 값을 담을 수 있는 공간이다.
# * Java 와는 다르게 Python 은 변수의 타입을 선언 시에 지정하지 않는다.
# * Python 은 런타임 시점에서 값을 보고 타입을 판단하게 된다.

# %%
user_question = "python 이 뭐야?"

print(user_question)
# Out:
# python 이 뭐야?

# %% [markdown]
# # 02. 변수 이름 작성 규칙
# * Python 에서는 보통 변수명을 snake_case 로 작성을 한다.
# * Java = Cammel_case
# * userName <- java
# * user_name <- python

# %%
model_name = "stt-ai-model"
max_token = 1000
temperature = 0.7
is_streaming = True

print(model_name)
print(max_token)
print(temperature)
print(is_streaming)
# Out:
# stt-ai-model
# 1000
# 0.7
# True

# %% [markdown]
# ## Python 의 자료형은 런타임 시 결정된다.
# * type() 함수로 변수의 타입을 확인할 수 있다.

# %%
print(type(model_name))
print(type(max_token))
print(type(temperature))
print(type(is_streaming))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = "raphael"
user_question = "RAG 가 뭐야?"

# 사용자 (raphael) 의 질문 : RAG 가 뭐야?

print(name + "의 질문 : " + user_question)

# f-string

message = f"{name}의 질문 : {user_question}"

print(message)
# Out:
# raphael의 질문 : RAG 가 뭐야?
# raphael의 질문 : RAG 가 뭐야?

# %% [markdown]
# ## 공부 Point
# * Java 와 비교하면서 어떤 부분이  Java 의 변수와 다른 것인가?
# * 변수의 선언과 할당이 무슨 차이가 있는가?
