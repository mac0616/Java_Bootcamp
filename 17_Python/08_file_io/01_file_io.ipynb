# %% [markdown]
# # 08. File Input / Output
#
# * File 입출력은 AI 서버와 RAG 에서 굉장히 빈번하게 사용이 된다.
# * AI Model 은 Data 가 많으면 많을 수록 정확도 있는 답변을 줄 수 있게 된다.
# * 또한, 회사에서는 Data 들이 다양한 형태 (.hwp, .csv, .txt, .pdf) 로 저장이 되어 있으며 해당 파일들을 읽어 Model 을 학습시키게 된다.
