# %% [markdown]
# # 01. FastAPI 서버 구축
# * Conda 가상환경 활성화
# * Uvicorn 설치(Spring 의 내장 Tomcat 역할)
#
# step01
# * pip install fastapi uvicorn
# ---
# step2
# * uvicorn main:app --reload
# * uvicorn : FastApi Application 을 실행하는 Server == Spring Tomcat
# * main : main.py 파일을 지칭한다.
# * app : main.py 내부에 존재하는 FastAPI 객체 변수명

# %% [markdown]
# * miniforge prompt
# * (base) C:\Users\user>conda activate pystudy_env
# * (pystudy_env) C:\Users\user>python --version
# * Python 3.12.13
# * (pystudy_env) C:\Users\user>pip install fastapi uvicorn
