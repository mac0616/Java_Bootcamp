# %% [markdown]
# # 08. Config
#
# * AI 관련 기능을 활용할 때 대부분 외부 API Key 를 발급 받아 사용을 하게 된다.
# * 외부 API Key 는 노출 시 과금이 발생하거나, 악용이 될 수 있기 때문에 환경 변수 설정이 중요하다.

# %%
# Python -DotEnv 설치하기
# 명령어 : pip install python-dotenv
# !pip install python-dotenv

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.14.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.15.0
# bleach                    6.4.0
# certifi                   2026.6.17
# cffi                      2.1.0
# charset-normalizer        3.4.8
# click                     8.4.2
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.21
# decorator                 5.3.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastapi                   0.139.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# ...
