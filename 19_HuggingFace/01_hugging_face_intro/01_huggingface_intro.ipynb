# %% [markdown]
# # Hugging Face 를 해보는 이유
# * 이번 챕터에서는 아래 AI 기능을 구현할 것이다.
# - 감정 분석
# - 문서 분류
# - 문서 요약
# - 객체 추출
#
# * 이러한 기능을 직접 AI 모델을 만들고 학습시키는 것은 현실적으로 불가능하다.
# * 따라서 이미 학습 된 AI 모델을 가져와 서비스에 적용하는 것이 일반적인 개발 방식이라고 생각하면 된다.
# * AI 모델들과 DataSet 들이 모여진 Github 같은 사이트가 "hugging face" 라는 플랫폼이다.

# %% [markdown]
# Hugging Face 를 활용하는 방법
#
# * 과거 방식
# - 모델 직접 학습
# - 모델 저장
# - 추론 코드 작성
#
# * Hugging Face 방식
# - 원하는 모델 검색
# - 모델을 다운로드
# - Pyhton 코드 작성

# %% [markdown]
# # Transformers
#
# * Python 에서 AI Model 을 쉽게 사용할 수 있도록 제공하는 라이브러리이다.
# * 대표적으로 아래 기능들을 제공한다.
#     * Pipline
#     * AutoTokenizer
#     * AutoModel
#     * AutoModelForSequenceClassification
#
# ---
# * Transformer
# - 트랜스포머는 자연어를 이해하기 위해 만들어진 딥러닝 모델 구조이다.
# - 현재 대부분의 LLM(GPT, Claude, Gemini) 과 NLP 모델은 트렌스포터 구조 기반으로 만들어져 있다.
#
# ---
# * AI Model 의 동작 방식
# - 문장 입력 -> Tokenizer -> 숫자로 변환 -> Transformer Model -> 예측 -> 결과 반환

# %%
# !pip install -r requirements.txt
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/122.1 MB ? eta -:--:--
#    ---------------------------------------- 1.3/122.1 MB 8.4 MB/s eta 0:00:15
#     --------------------------------------- 2.6/122.1 MB 6.9 MB/s eta 0:00:18
#    - -------------------------------------- 4.2/122.1 MB 7.2 MB/s eta 0:00:17
#    - -------------------------------------- 5.5/122.1 MB 7.1 MB/s eta 0:00:17
#    -- ------------------------------------- 7.3/122.1 MB 7.3 MB/s eta 0:00:16
#    -- ------------------------------------- 8.9/122.1 MB 7.3 MB/s eta 0:00:16
#    --- ------------------------------------ 10.0/122.1 MB 7.1 MB/s eta 0:00:16
#    --- ------------------------------------ 11.5/122.1 MB 7.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 12.6/122.1 MB 7.1 MB/s eta 0:00:16
#    ---- ----------------------------------- 13.4/122.1 MB 6.6 MB/s eta 0:00:17
#    ---- ----------------------------------- 14.4/122.1 MB 6.5 MB/s eta 0:00:17
# ...
